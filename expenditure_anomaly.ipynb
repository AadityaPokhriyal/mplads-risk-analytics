# %% [markdown]
# <a href="https://colab.research.google.com/github/AadityaPokhriyal/mplads-risk-analytics/blob/main/expenditure_anomaly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler

# %%
#start
# Out:
# 24
